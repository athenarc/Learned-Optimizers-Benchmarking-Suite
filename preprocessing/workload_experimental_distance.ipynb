# %%
import os
from config import query_directory, TABLES, DB_CONFIG, connect_to_db
from typing import List, Dict, Tuple
from file_utils import read_queries_from_directory, write_query_results_to_file
import pandas as pd
from tqdm import tqdm
from sql_parser import parse_sql
from query_template import get_query_template
from collections import defaultdict
import networkx as nx
import pandas as pd
from sql_parser import parse_sql
import matplotlib.pyplot as plt
from sql_parser import parse_sql

from pathlib import Path
try:
    # Works when running from a .py file
    REPO_ROOT = Path(__file__).resolve()
except NameError:
    # Fallback for notebooks — use current working directory
    REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT.name != "Learned-Optimizers-Benchmarking-Suite" and REPO_ROOT.parent != REPO_ROOT:
    REPO_ROOT = REPO_ROOT.parent

job = f"{REPO_ROOT}/workloads/imdb_pg_dataset/job"
job_dynamic = f"{REPO_ROOT}/workloads/imdb_pg_dataset/job_dynamic"
job_extended = f"{REPO_ROOT}/workloads/imdb_pg_dataset/job_extended"

# %%
from query_template import get_query_template_no_correl
from config import connect_to_db
from selectivity import DatabaseCache
import os
import re
from query_template import SQLInfoExtractor
import pglast

def build_query_profile(parsed_query: dict, query_name: str, query_info: dict, query: str, alias_mapping: Dict[str, str] = None) -> dict:
    sql_operator_pattern = re.compile(
        r'(>=|<=|!=|=|>|<|LIKE|like|IN|BETWEEN|IS\s+NOT\s+NULL|IS\s+NULL|NOT\s*(=|LIKE|like|IN|BETWEEN))'
    )

    node = pglast.parse_sql(query)
    extractor = SQLInfoExtractor()
    extractor(node)
    
    info = extractor.info

    selected_columns = []
    for column in parsed_query.get('select_columns', []):
        if '.' in column:
            table, column_name = column.split('.', 1)
            if alias_mapping and table in alias_mapping:
                table = alias_mapping[table]
            selected_columns.append((table, column_name))

    # Process join enumeration
    join_enumeration = []
    for i, join in enumerate(query_info.get('join_details', []), 1):
        join_entry = {
            'join_number': f'join{i}',
            'tables': join['tables'],
            'condition': join['condition'],
            'actual_rows': None
        }
        if 'execution_data' in join:
            join_entry['actual_rows'] = join['execution_data'].get('actual_rows')
        join_enumeration.append(join_entry)

    profile = {
        'query_name': query_name,
        'num_joins': len(parsed_query.get('joins', [])),
        'num_tables': len(set(parsed_query.get('from_tables', []))),
        'selected_columns': sorted(selected_columns),
        'num_columns_selected': len(parsed_query.get('select_columns', [])),
        'num_predicates': len(parsed_query.get('filters', [])),
        'low_selectivity_predicates': 0,
        'high_selectivity_predicates': 0,
        'tables': sorted(info.get('tables', [])),
        'predicates': sorted(info.get('predicates', [])),
        'joins': parsed_query.get('joins', []),
        'join_details': query_info.get('join_details', []),
        'join_enumeration': join_enumeration
    }

    for table, filters in query_info.get('filters', {}).items():
        for column, value in filters.items():
            if isinstance(value, float):  # valid selectivity
                selectivity = value
                if selectivity <= 0.05:
                    profile['low_selectivity_predicates'] += 1
                else:
                    profile['high_selectivity_predicates'] += 1
    
    return profile

def process_queries_in_directory(directory: str, db_cache: DatabaseCache):
    results = []
    sql_files = [f for f in os.listdir(directory) if f.endswith(".sql")]
    query_profiles = []
    # sql_files = ['31c.sql']
    for filename in tqdm(sql_files, desc="Processing SQL files", unit="file"):
        filepath = os.path.join(directory, filename)
        try:
            with open(filepath, "r") as file:
                query = file.read().strip()
                if query:
                    parsed_query = parse_sql(query, split_parentheses=True)
                    aliases = parsed_query.get('aliases', {})
                    query_info = get_query_template_no_correl(parsed_query, db_cache, alias_mapping=aliases, original_query=query)
                    profile = build_query_profile(parsed_query, filename, query_info, query, alias_mapping=aliases)
                    query_profiles.append(profile)
                    results.append((filename, query_info))
        except IOError as e:
            print(f"Error reading file {filename}: {e}")
    
    return results, query_profiles

# %%
conn = connect_to_db()
db_cache = DatabaseCache(conn)
db_cache.preload_all_tables()
conn.close()
# Out:
# Loaded 901,343 rows from aka_name
# Loaded 361,472 rows from aka_title
# Loaded 36,244,344 rows from cast_info
# Loaded 3,140,339 rows from char_name
# Loaded 4 rows from comp_cast_type
# Loaded 234,997 rows from company_name
# Loaded 4 rows from company_type
# Loaded 135,086 rows from complete_cast
# Loaded 113 rows from info_type
# Loaded 134,170 rows from keyword
# Loaded 7 rows from kind_type
# Loaded 18 rows from link_type
# Loaded 2,609,129 rows from movie_companies
# Loaded 14,835,720 rows from movie_info
# Loaded 1,380,035 rows from movie_info_idx
# Loaded 4,523,930 rows from movie_keyword
# Loaded 29,997 rows from movie_link
# Loaded 4,167,491 rows from name
# Loaded 2,963,664 rows from person_info
# Loaded 12 rows from role_type
# Loaded 2,528,312 rows from title

# %%
results, query_profiles_job = process_queries_in_directory(query_directory, db_cache)
job_original_profiles = pd.DataFrame(query_profiles_job)
# Out:
# Processing SQL files:   0%|          | 0/113 [00:00<?, ?file/s]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   1%|          | 1/113 [00:02<04:54,  2.63s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   2%|▏         | 2/113 [00:08<08:05,  4.37s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   3%|▎         | 3/113 [00:08<04:43,  2.58s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   4%|▎         | 4/113 [00:15<07:28,  4.11s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   4%|▍         | 5/113 [00:25<11:37,  6.45s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   5%|▌         | 6/113 [00:32<11:55,  6.69s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   6%|▌         | 7/113 [00:38<11:22,  6.44s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   7%|▋         | 8/113 [00:44<10:58,  6.27s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   8%|▊         | 9/113 [00:44<07:34,  4.37s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   9%|▉         | 10/113 [00:46<05:46,  3.36s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  10%|▉         | 11/113 [00:46<04:23,  2.58s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  11%|█         | 12/113 [00:48<03:51,  2.29s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  12%|█▏        | 13/113 [00:48<02:48,  1.69s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  12%|█▏        | 14/113 [00:50<02:37,  1.59s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  13%|█▎        | 15/113 [00:54<03:50,  2.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  14%|█▍        | 16/113 [00:57<04:19,  2.68s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  15%|█▌        | 17/113 [01:08<08:03,  5.04s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  16%|█▌        | 18/113 [01:08<05:50,  3.69s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  17%|█▋        | 19/113 [01:10<05:00,  3.20s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  18%|█▊        | 20/113 [01:10<03:33,  2.29s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  19%|█▊        | 21/113 [01:12<03:01,  1.97s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  19%|█▉        | 22/113 [01:12<02:11,  1.44s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  20%|██        | 23/113 [01:12<01:39,  1.11s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  21%|██        | 24/113 [01:14<02:00,  1.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  22%|██▏       | 25/113 [01:18<02:56,  2.01s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  23%|██▎       | 26/113 [01:20<02:52,  1.98s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  24%|██▍       | 27/113 [01:21<02:40,  1.86s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  25%|██▍       | 28/113 [01:31<05:58,  4.22s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  26%|██▌       | 29/113 [01:33<04:48,  3.44s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  27%|██▋       | 30/113 [01:34<03:56,  2.86s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  27%|██▋       | 31/113 [01:36<03:31,  2.59s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  28%|██▊       | 32/113 [01:41<04:17,  3.18s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  29%|██▉       | 33/113 [01:41<03:03,  2.29s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  30%|███       | 34/113 [01:44<03:14,  2.47s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  31%|███       | 35/113 [01:44<02:27,  1.89s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  32%|███▏      | 36/113 [01:45<01:57,  1.53s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  33%|███▎      | 37/113 [01:46<01:39,  1.31s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  34%|███▎      | 38/113 [01:48<02:06,  1.68s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  35%|███▍      | 39/113 [01:56<04:28,  3.63s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  35%|███▌      | 40/113 [01:58<03:39,  3.01s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  36%|███▋      | 41/113 [01:59<02:43,  2.27s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  37%|███▋      | 42/113 [02:00<02:22,  2.01s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  38%|███▊      | 43/113 [02:05<03:14,  2.78s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  39%|███▉      | 44/113 [02:07<03:01,  2.62s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  40%|███▉      | 45/113 [02:13<04:12,  3.71s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  41%|████      | 46/113 [02:14<03:19,  2.98s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  42%|████▏     | 47/113 [02:15<02:35,  2.36s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  42%|████▏     | 48/113 [02:20<03:16,  3.02s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  43%|████▎     | 49/113 [02:26<04:19,  4.06s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  44%|████▍     | 50/113 [02:31<04:23,  4.18s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  45%|████▌     | 51/113 [02:33<03:37,  3.51s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  46%|████▌     | 52/113 [02:34<02:59,  2.94s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  47%|████▋     | 53/113 [02:35<02:17,  2.29s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  48%|████▊     | 54/113 [02:36<01:53,  1.92s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  49%|████▊     | 55/113 [02:36<01:24,  1.46s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  50%|████▉     | 56/113 [02:40<02:06,  2.21s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  50%|█████     | 57/113 [02:46<03:05,  3.30s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  51%|█████▏    | 58/113 [02:47<02:17,  2.51s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  52%|█████▏    | 59/113 [02:53<03:14,  3.59s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  53%|█████▎    | 60/113 [02:56<02:59,  3.38s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  54%|█████▍    | 61/113 [02:57<02:19,  2.68s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  55%|█████▍    | 62/113 [02:57<01:37,  1.91s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  56%|█████▌    | 63/113 [03:01<02:01,  2.44s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  57%|█████▋    | 64/113 [03:02<01:36,  1.97s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  58%|█████▊    | 65/113 [03:05<01:53,  2.37s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  58%|█████▊    | 66/113 [03:06<01:34,  2.01s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  59%|█████▉    | 67/113 [03:09<01:38,  2.15s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  60%|██████    | 68/113 [03:10<01:23,  1.86s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  61%|██████    | 69/113 [03:12<01:29,  2.04s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  62%|██████▏   | 70/113 [03:14<01:19,  1.85s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  63%|██████▎   | 71/113 [03:14<00:56,  1.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  64%|██████▎   | 72/113 [03:20<01:49,  2.66s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  65%|██████▍   | 73/113 [03:31<03:30,  5.27s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  65%|██████▌   | 74/113 [03:33<02:42,  4.16s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  66%|██████▋   | 75/113 [03:37<02:42,  4.27s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  67%|██████▋   | 76/113 [03:40<02:18,  3.76s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  68%|██████▊   | 77/113 [03:42<02:00,  3.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  69%|██████▉   | 78/113 [03:43<01:34,  2.69s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  70%|██████▉   | 79/113 [04:01<04:02,  7.15s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  71%|███████   | 80/113 [04:03<03:10,  5.76s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  72%|███████▏  | 81/113 [04:04<02:12,  4.15s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  73%|███████▎  | 82/113 [04:05<01:44,  3.39s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  73%|███████▎  | 83/113 [04:07<01:31,  3.06s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  74%|███████▍  | 84/113 [04:12<01:45,  3.63s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  75%|███████▌  | 85/113 [04:13<01:17,  2.79s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  76%|███████▌  | 86/113 [04:23<02:09,  4.81s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  77%|███████▋  | 87/113 [04:27<02:02,  4.71s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  78%|███████▊  | 88/113 [04:32<02:00,  4.84s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  79%|███████▉  | 89/113 [04:33<01:26,  3.62s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  80%|███████▉  | 90/113 [04:34<01:04,  2.79s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  81%|████████  | 91/113 [04:37<01:04,  2.94s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  81%|████████▏ | 92/113 [04:39<00:53,  2.55s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  82%|████████▏ | 93/113 [04:43<01:00,  3.03s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  83%|████████▎ | 94/113 [04:52<01:30,  4.76s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  84%|████████▍ | 95/113 [04:54<01:10,  3.94s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  85%|████████▍ | 96/113 [04:57<01:01,  3.64s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  86%|████████▌ | 97/113 [05:01<00:59,  3.70s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  87%|████████▋ | 98/113 [05:06<01:02,  4.18s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  88%|████████▊ | 99/113 [05:09<00:53,  3.80s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  88%|████████▊ | 100/113 [05:13<00:50,  3.88s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  89%|████████▉ | 101/113 [05:20<00:57,  4.78s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  90%|█████████ | 102/113 [05:21<00:40,  3.73s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  91%|█████████ | 103/113 [05:27<00:43,  4.34s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  92%|█████████▏| 104/113 [05:30<00:36,  4.06s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  93%|█████████▎| 105/113 [05:39<00:43,  5.47s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  94%|█████████▍| 106/113 [05:40<00:29,  4.15s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  95%|█████████▍| 107/113 [05:41<00:18,  3.01s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  96%|█████████▌| 108/113 [05:44<00:16,  3.25s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  96%|█████████▋| 109/113 [05:46<00:11,  2.81s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  97%|█████████▋| 110/113 [05:49<00:08,  2.92s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  98%|█████████▊| 111/113 [05:50<00:04,  2.13s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  99%|█████████▉| 112/113 [05:50<00:01,  1.70s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files: 100%|██████████| 113/113 [05:52<00:00,  3.12s/file]

# %%
results, query_profiles_job = process_queries_in_directory(query_directory_variation, db_cache)
job_modified_profiles = pd.DataFrame(query_profiles_job)
# Out:
# Processing SQL files:   0%|          | 0/113 [00:00<?, ?file/s]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   1%|          | 1/113 [00:01<03:00,  1.61s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   2%|▏         | 2/113 [00:08<08:32,  4.61s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   3%|▎         | 3/113 [00:08<04:58,  2.71s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   4%|▎         | 4/113 [00:09<03:50,  2.11s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   4%|▍         | 5/113 [00:15<06:16,  3.49s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   5%|▌         | 6/113 [00:17<04:58,  2.79s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   6%|▌         | 7/113 [00:22<06:24,  3.63s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   7%|▋         | 8/113 [00:23<04:48,  2.75s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   8%|▊         | 9/113 [00:23<03:23,  1.96s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:   9%|▉         | 10/113 [00:24<02:49,  1.64s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  10%|▉         | 11/113 [00:25<02:22,  1.39s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  11%|█         | 12/113 [00:27<02:27,  1.46s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  12%|█▏        | 13/113 [00:27<01:49,  1.09s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  12%|█▏        | 14/113 [00:28<01:51,  1.13s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  13%|█▎        | 15/113 [00:32<03:06,  1.90s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  14%|█▍        | 16/113 [00:36<03:57,  2.45s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  15%|█▌        | 17/113 [00:47<08:20,  5.21s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  16%|█▌        | 18/113 [00:48<06:05,  3.84s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  17%|█▋        | 19/113 [00:50<05:07,  3.27s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  18%|█▊        | 20/113 [00:50<03:38,  2.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  19%|█▊        | 21/113 [00:51<02:57,  1.93s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  19%|█▉        | 22/113 [00:51<02:09,  1.42s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  20%|██        | 23/113 [00:52<01:39,  1.10s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  21%|██        | 24/113 [00:53<01:53,  1.27s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  22%|██▏       | 25/113 [00:56<02:39,  1.81s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  23%|██▎       | 26/113 [00:58<02:40,  1.85s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  24%|██▍       | 27/113 [00:59<02:22,  1.65s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  25%|██▍       | 28/113 [01:10<06:09,  4.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  26%|██▌       | 29/113 [01:11<04:50,  3.46s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  27%|██▋       | 30/113 [01:13<03:58,  2.87s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  27%|██▋       | 31/113 [01:14<03:20,  2.45s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  28%|██▊       | 32/113 [01:19<04:06,  3.04s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  29%|██▉       | 33/113 [01:19<02:55,  2.19s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  30%|███       | 34/113 [01:22<03:22,  2.56s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  31%|███       | 35/113 [01:23<02:31,  1.94s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  32%|███▏      | 36/113 [01:24<02:03,  1.60s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  33%|███▎      | 37/113 [01:25<01:46,  1.40s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  34%|███▎      | 38/113 [01:28<02:21,  1.89s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  35%|███▍      | 39/113 [01:35<04:28,  3.63s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  35%|███▌      | 40/113 [01:37<03:43,  3.06s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  36%|███▋      | 41/113 [01:38<02:46,  2.31s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  37%|███▋      | 42/113 [01:39<02:22,  2.01s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  38%|███▊      | 43/113 [01:44<03:25,  2.94s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  39%|███▉      | 44/113 [01:46<03:09,  2.75s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  40%|███▉      | 45/113 [01:48<02:34,  2.28s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  41%|████      | 46/113 [01:49<02:08,  1.92s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  42%|████▏     | 47/113 [01:49<01:45,  1.59s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  42%|████▏     | 48/113 [01:54<02:42,  2.49s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  43%|████▎     | 49/113 [01:55<02:14,  2.10s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  44%|████▍     | 50/113 [01:59<02:48,  2.68s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  45%|████▌     | 51/113 [02:01<02:29,  2.42s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  46%|████▌     | 52/113 [02:03<02:11,  2.15s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  47%|████▋     | 53/113 [02:03<01:44,  1.74s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  48%|████▊     | 54/113 [02:05<01:33,  1.58s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  49%|████▊     | 55/113 [02:05<01:10,  1.21s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  50%|████▉     | 56/113 [02:08<01:44,  1.83s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  50%|█████     | 57/113 [02:13<02:37,  2.81s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  51%|█████▏    | 58/113 [02:14<01:59,  2.17s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  52%|█████▏    | 59/113 [02:20<03:05,  3.43s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  53%|█████▎    | 60/113 [02:24<02:58,  3.37s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  54%|█████▍    | 61/113 [02:25<02:19,  2.68s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  55%|█████▍    | 62/113 [02:25<01:37,  1.91s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  56%|█████▌    | 63/113 [02:28<01:57,  2.34s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  57%|█████▋    | 64/113 [02:29<01:33,  1.90s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  58%|█████▊    | 65/113 [02:31<01:39,  2.07s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  58%|█████▊    | 66/113 [02:33<01:25,  1.81s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  59%|█████▉    | 67/113 [02:35<01:30,  1.97s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  60%|██████    | 68/113 [02:36<01:20,  1.79s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  61%|██████    | 69/113 [02:39<01:27,  1.99s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  62%|██████▏   | 70/113 [02:40<01:19,  1.84s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  63%|██████▎   | 71/113 [02:41<00:56,  1.34s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  64%|██████▎   | 72/113 [02:45<01:37,  2.37s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  65%|██████▍   | 73/113 [02:56<03:13,  4.83s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  65%|██████▌   | 74/113 [02:57<02:28,  3.81s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  66%|██████▋   | 75/113 [03:02<02:30,  3.95s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  67%|██████▋   | 76/113 [03:04<02:05,  3.38s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  68%|██████▊   | 77/113 [03:06<01:45,  2.94s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  69%|██████▉   | 78/113 [03:07<01:23,  2.39s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  70%|██████▉   | 79/113 [03:23<03:47,  6.68s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  71%|███████   | 80/113 [03:26<02:57,  5.39s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  72%|███████▏  | 81/113 [03:26<02:04,  3.90s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  73%|███████▎  | 82/113 [03:28<01:39,  3.20s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  73%|███████▎  | 83/113 [03:30<01:29,  2.97s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  74%|███████▍  | 84/113 [03:35<01:43,  3.57s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  75%|███████▌  | 85/113 [03:36<01:16,  2.75s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  76%|███████▌  | 86/113 [03:46<02:11,  4.87s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  77%|███████▋  | 87/113 [03:50<02:04,  4.77s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  78%|███████▊  | 88/113 [03:55<01:55,  4.61s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  79%|███████▉  | 89/113 [03:55<01:21,  3.41s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  80%|███████▉  | 90/113 [03:56<01:01,  2.66s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  81%|████████  | 91/113 [03:59<00:58,  2.67s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  81%|████████▏ | 92/113 [04:00<00:45,  2.18s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  82%|████████▏ | 93/113 [04:03<00:50,  2.50s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  83%|████████▎ | 94/113 [04:10<01:10,  3.70s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  84%|████████▍ | 95/113 [04:11<00:52,  2.92s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  85%|████████▍ | 96/113 [04:12<00:43,  2.55s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  86%|████████▌ | 97/113 [04:14<00:37,  2.36s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  87%|████████▋ | 98/113 [04:19<00:44,  2.96s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  88%|████████▊ | 99/113 [04:21<00:40,  2.88s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  88%|████████▊ | 100/113 [04:23<00:33,  2.61s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  89%|████████▉ | 101/113 [04:30<00:47,  3.97s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  90%|█████████ | 102/113 [04:32<00:34,  3.15s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  91%|█████████ | 103/113 [04:35<00:30,  3.06s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  92%|█████████▏| 104/113 [04:36<00:23,  2.62s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  93%|█████████▎| 105/113 [04:43<00:32,  4.03s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  94%|█████████▍| 106/113 [04:44<00:21,  3.03s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  95%|█████████▍| 107/113 [04:44<00:13,  2.21s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  96%|█████████▌| 108/113 [04:47<00:11,  2.24s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  96%|█████████▋| 109/113 [04:48<00:07,  1.99s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  97%|█████████▋| 110/113 [04:51<00:06,  2.28s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  98%|█████████▊| 111/113 [04:51<00:03,  1.69s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files:  99%|█████████▉| 112/113 [04:52<00:01,  1.35s/file]/data/hdd1/users/kmparmp/Learned-Optimizers-Benchmarking-Suite/preprocessing/selectivity.py:437: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Processing SQL files: 100%|██████████| 113/113 [04:54<00:00,  2.60s/file]

# %%
from typing import List, Dict, Any
from collections import defaultdict
from distribution import MetadataDistribution

TYPES = ["tables", "predicates", "selected_columns", "join_enumeration"]

def build_workload_distributions(query_profiles: List[Dict[str, Any]], use_predefined_bins: bool = False, config: Dict = None):
    """
    Build MetadataDistribution for each feature type from a list of query profiles.
    """
    workload_data = defaultdict(list)

    for profile in query_profiles:
        for t in TYPES:
            values = profile.get(t, [])
            # Store the values as lists (ensure hashability)
            workload_data[t].append(values)

    dists = {}

    for t in TYPES:
        data = workload_data[t]
        if use_predefined_bins and config and "bin_values" in config and t in config["bin_values"]:
            slots = config["bin_values"][t]
            dists[t] = MetadataDistribution(t, data, slots=slots)
        else:
            dists[t] = MetadataDistribution(t, data)

    return dists

# Build distributions for both workloads
dists_job_original = build_workload_distributions(job_original_profiles.to_dict(orient='records'))
dists_job_modified = build_workload_distributions(job_modified_profiles.to_dict(orient='records'))
# Out:
# MetadataDistribution: tables with 113 items
# MetadataDistribution: predicates with 113 items
# MetadataDistribution: selected_columns with 113 items
# MetadataDistribution: join_enumeration with 113 items
# MetadataDistribution: tables with 113 items
# MetadataDistribution: predicates with 113 items
# MetadataDistribution: selected_columns with 113 items
# MetadataDistribution: join_enumeration with 113 items

# %%
from collections import Counter
from scipy.spatial.distance import jensenshannon
import numpy as np

def compute_workload_distance_from_dists(dists1: Dict[str, MetadataDistribution], dists2: Dict[str, MetadataDistribution]) -> float:
    distances = []

    for key in TYPES:
        dist1_obj = dists1.get(key)
        dist2_obj = dists2.get(key)
        
        if dist1_obj is None or dist2_obj is None:
            continue

        dist1 = dist1_obj.get()
        dist2 = dist2_obj.get()

        if type == "selected_columns":
            print(dist2)
            
        import json
        def make_hashable_key(k):
            return json.dumps(k, sort_keys=True)
        
        dist1_serialized = pd.Series(
            {make_hashable_key(k): v for k, v in dist1.items()}
        )
        dist2_serialized = pd.Series(
            {make_hashable_key(k): v for k, v in dist2.items()}
        )

        all_bins = dist1_serialized.index.union(dist2_serialized.index)

        p = np.array([dist1_serialized.get(k, 0.0) for k in all_bins])
        q = np.array([dist2_serialized.get(k, 0.0) for k in all_bins])
        p = p / (p.sum() if p.sum() != 0 else 1)
        q = q / (q.sum() if q.sum() != 0 else 1)
        jsd = jensenshannon(p, q)
        print(f"Jensen-Shannon Divergence for {key}: {jsd}")
        distances.append(jsd)

    return float(np.mean(distances)) if distances else 0.0

distance = compute_workload_distance_from_dists(dists_job_original, dists_job_modified)
print("Workload distance (Jensen-Shannon Divergence):", distance)
# Out:
# Jensen-Shannon Divergence for tables: 0.0
# Jensen-Shannon Divergence for predicates: 0.0
# Jensen-Shannon Divergence for selected_columns: 0.15664029935700752
# Jensen-Shannon Divergence for join_enumeration: 0.0
# Workload distance (Jensen-Shannon Divergence): 0.03916007483925188
